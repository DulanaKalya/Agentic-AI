# %%
from typing import TypedDict, Annotated
from langgraph.graph import add_messages, StateGraph, END
from langchain_groq import ChatGroq
from langchain_core.messages import AIMessage, HumanMessage
from dotenv import load_dotenv
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.prebuilt import ToolNode

load_dotenv()

class ChildState(TypedDict):
    messages: Annotated[list, add_messages]

search_tool = TavilySearchResults(max_results=2)
tools = [search_tool]

llm = ChatGroq(model="llama-3.1-8b-instant")

llm_with_tools = llm.bind_tools(tools=tools)

def agent(state: ChildState):
    return {
        "messages": [llm_with_tools.invoke(state["messages"])], 
    }

def tools_router(state: ChildState):
    last_message = state["messages"][-1]

    if(hasattr(last_message, "tool_calls") and len(last_message.tool_calls) > 0):
        return "tool_node"
    else: 
        return END
    

tool_node = ToolNode(tools=tools)

subgraph = StateGraph(ChildState)

subgraph.add_node("agent", agent)
subgraph.add_node("tool_node", tool_node)
subgraph.set_entry_point("agent")

subgraph.add_conditional_edges("agent", tools_router)
subgraph.add_edge("tool_node", "agent")

search_app = subgraph.compile()

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

display(
    Image(
        search_app.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API
        )
    )
)

# %%
search_app.invoke({"messages": [HumanMessage(content="How is the weather in Chennai?")]})
# Out:
# {'messages': [HumanMessage(content='How is the weather in Chennai?', additional_kwargs={}, response_metadata={}, id='f5f6d263-98a4-4fa8-9036-6bc5724b84dd'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'ab3bdvj21', 'function': {'arguments': '{"query":"Chennai weather"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 285, 'total_tokens': 305, 'completion_time': 0.039713658, 'prompt_time': 0.022152844, 'queue_time': 0.050677726, 'total_time': 0.061866502}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--5312c967-2f2b-4135-8722-7e1b1b5c00b9-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Chennai weather'}, 'id': 'ab3bdvj21', 'type': 'tool_call'}], usage_metadata={'input_tokens': 285, 'output_tokens': 20, 'total_tokens': 305}),
#   ToolMessage(content='[{"url": "https://timesofindia.indiatimes.com/city/chennai/chennai-weather-forecast-moderate-rain-and-humidity-expected-today/articleshow/124492233.cms", "content": "The data for this weather forecast has been sourced from AQI.in, providing residents with comprehensive information to plan their daily activities and weekly schedules accordingly.Chennai is expected to experience moderate rainfall on October 12, 2025, with temperatures ranging between 25.8°C and 31.3°C, amid overcast skies and 71% humidity. The city\'s air quality index recorded yesterday at 81 indicates moderate pollution levels, which may persist due to the damp conditions. [...] Chennai expects moderate rain today with temperatures ranging from 25.8°C to 31.3°C and high humidity. Yesterday’s air quality was moderate (AQI 81), potentially lingering. Residents are advised to carry umbrellas and consider masks in traffic. The forecast indicates continuous rain throughout the upcoming week, making morning hours the best for outdoor activities before precipitation sets in. [...] The week ahead shows consistent rainy conditions in Chennai. October 13 will see patchy rain with temperatures between 25.3°C and 31.3°C. October 14 brings light rain with highs of 31°C and lows of 25.5°C.Temperatures from October 15 to 16 will range between 25.6°C and 31.6°C with continued rainfall. October 17 and 18 maintain the rainy pattern with temperatures between 25.6°C and 30.7°C.Yesterday\'s air quality reading of 81 showed improvement compared to the previous week\'s average. The"}, {"url": "https://weatherspark.com/h/y/110123/2025/Historical-Weather-during-2025-in-Chennai-Tamil-Nadu-India", "content": "| ---   194019501960197019801990200020102020   ---   2016201720182019202020212022202320242025   ---   SpringSummerFallWinter  JanFebMarAprMayJunJulAugSepOctNovDec 2025 Weather History in Chennai Tamil Nadu, India The data for this report comes from the Chennai International Airport. See all nearby weather stations  Latest Report — 3:30 PM Sat, Dec 6, 2025    23 min ago    UTC 10:00  Call Sign VOMM  Temp.  84°F warm   |  |  |  --- | | Dew Pt. | 75°F  miserable | | Rel. Humidity | 75% | [...] Chennai Link  Download  Compare  Averages  History:202520242023202220212020201920182017  frigid   15°F   freezing   32°F   very cold   45°F   cold   55°F   cool   65°F   comfortable   75°F   warm   85°F   hot   95°F   sweltering  The hourly reported temperature, color coded into bands. The shaded overlays indicate night and civil twilight.  © OpenStreetMap contributors  Compare Chennai to another city:  Cloud Cover in 2025 in Chennai Link  Download  Compare  Averages"}]', name='tavily_search_results_json', id='24dc4456-bdc6-4a1e-8dc9-d487fc0ceac7', tool_call_id='ab3bdvj21', artifact={'query': 'Chennai weather', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://timesofindia.indiatimes.com/city/chennai/chennai-weather-forecast-moderate-rain-and-humidity-expected-today/articleshow/124492233.cms', 'title': 'Chennai weather: High humidity, rain expected today; AQI remains ...', 'content': "The data for this weather forecast has been sourced from AQI.in, providing residents with comprehensive information to plan their daily activities and weekly schedules accordingly.Chennai is expected to experience moderate rainfall on October 12, 2025, with temperatures ranging between 25.8°C and 31.3°C, amid overcast skies and 71% humidity. The city's air quality index recorded yesterday at 81 indicates moderate pollution levels, which may persist due to the damp conditions. [...] Chennai expects moderate rain today with temperatures ranging from 25.8°C to 31.3°C and high humidity. Yesterday’s air quality was moderate (AQI 81), potentially lingering. Residents are advised to carry umbrellas and consider masks in traffic. The forecast indicates continuous rain throughout the upcoming week, making morning hours the best for outdoor activities before precip ...
#   AIMessage(content='The current weather in Chennai is expected to be moderate with rainfall, temperatures ranging from 25.8°C to 31.3°C, and high humidity. The air quality index recorded yesterday was 81, indicating moderate pollution levels. Residents are advised to carry umbrellas and consider masks in traffic. The forecast indicates continuous rain throughout the upcoming week, making morning hours the best for outdoor activities before precipitation sets in.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 84, 'prompt_tokens': 990, 'total_tokens': 1074, 'completion_time': 0.134500165, 'prompt_time': 0.066467866, 'queue_time': 0.056902054, 'total_time': 0.200968031}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'finish_reason': 'stop', 'logprobs': None}, id='run--d3f52ac9-173d-4002-a0ce-4f74a85fc1a0-0', usage_metadata={'input_tokens': 990, 'output_tokens': 84, 'total_tokens': 1074})]}

# %% [markdown]
# Case 1: Shared Schema (Direct Embedding)

# %%
from typing import TypedDict, Annotated
from langgraph.graph import add_messages, StateGraph, START, END
from langchain_core.messages import HumanMessage

# Define parent graph with the same schema
class ParentState(TypedDict):
    messages: Annotated[list, add_messages]

# Create parent graph
parent_graph = StateGraph(ParentState)

# Add the subgraph as a node
parent_graph.add_node("search_agent", search_app)

# Connect the flow
parent_graph.add_edge(START, "search_agent")
parent_graph.add_edge("search_agent", END)

# Compile parent graph
parent_app = parent_graph.compile()

# Run the parent graph
result = parent_app.invoke({"messages": [HumanMessage(content="How is the weather in Chennai?")]})
result
# Out:
# {'messages': [HumanMessage(content='How is the weather in Chennai?', additional_kwargs={}, response_metadata={}, id='76dbe918-a580-4367-8532-b9aee8198a20'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '4pfk62a9j', 'function': {'arguments': '{"query":"Chennai weather"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 285, 'total_tokens': 305, 'completion_time': 0.033815586, 'prompt_time': 0.016627196, 'queue_time': 0.054458343, 'total_time': 0.050442782}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--32f608df-0fcc-4f3a-97fe-451a5f6d5fc3-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'Chennai weather'}, 'id': '4pfk62a9j', 'type': 'tool_call'}], usage_metadata={'input_tokens': 285, 'output_tokens': 20, 'total_tokens': 305}),
#   ToolMessage(content='[{"url": "https://timesofindia.indiatimes.com/city/chennai/chennai-weather-forecast-moderate-rain-and-humidity-expected-today/articleshow/124492233.cms", "content": "The data for this weather forecast has been sourced from AQI.in, providing residents with comprehensive information to plan their daily activities and weekly schedules accordingly.Chennai is expected to experience moderate rainfall on October 12, 2025, with temperatures ranging between 25.8°C and 31.3°C, amid overcast skies and 71% humidity. The city\'s air quality index recorded yesterday at 81 indicates moderate pollution levels, which may persist due to the damp conditions. [...] Chennai expects moderate rain today with temperatures ranging from 25.8°C to 31.3°C and high humidity. Yesterday’s air quality was moderate (AQI 81), potentially lingering. Residents are advised to carry umbrellas and consider masks in traffic. The forecast indicates continuous rain throughout the upcoming week, making morning hours the best for outdoor activities before precipitation sets in. [...] The week ahead shows consistent rainy conditions in Chennai. October 13 will see patchy rain with temperatures between 25.3°C and 31.3°C. October 14 brings light rain with highs of 31°C and lows of 25.5°C.Temperatures from October 15 to 16 will range between 25.6°C and 31.6°C with continued rainfall. October 17 and 18 maintain the rainy pattern with temperatures between 25.6°C and 30.7°C.Yesterday\'s air quality reading of 81 showed improvement compared to the previous week\'s average. The"}, {"url": "https://weatherspark.com/h/y/110123/2025/Historical-Weather-during-2025-in-Chennai-Tamil-Nadu-India", "content": "| ---   194019501960197019801990200020102020   ---   2016201720182019202020212022202320242025   ---   SpringSummerFallWinter  JanFebMarAprMayJunJulAugSepOctNovDec 2025 Weather History in Chennai Tamil Nadu, India The data for this report comes from the Chennai International Airport. See all nearby weather stations  Latest Report — 3:30 PM Sat, Dec 6, 2025    23 min ago    UTC 10:00  Call Sign VOMM  Temp.  84°F warm   |  |  |  --- | | Dew Pt. | 75°F  miserable | | Rel. Humidity | 75% | [...] Chennai Link  Download  Compare  Averages  History:202520242023202220212020201920182017  frigid   15°F   freezing   32°F   very cold   45°F   cold   55°F   cool   65°F   comfortable   75°F   warm   85°F   hot   95°F   sweltering  The hourly reported temperature, color coded into bands. The shaded overlays indicate night and civil twilight.  © OpenStreetMap contributors  Compare Chennai to another city:  Cloud Cover in 2025 in Chennai Link  Download  Compare  Averages"}]', name='tavily_search_results_json', id='3940b9a5-bd13-48d5-a418-2e9588751f8e', tool_call_id='4pfk62a9j', artifact={'query': 'Chennai weather', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://timesofindia.indiatimes.com/city/chennai/chennai-weather-forecast-moderate-rain-and-humidity-expected-today/articleshow/124492233.cms', 'title': 'Chennai weather: High humidity, rain expected today; AQI remains ...', 'content': "The data for this weather forecast has been sourced from AQI.in, providing residents with comprehensive information to plan their daily activities and weekly schedules accordingly.Chennai is expected to experience moderate rainfall on October 12, 2025, with temperatures ranging between 25.8°C and 31.3°C, amid overcast skies and 71% humidity. The city's air quality index recorded yesterday at 81 indicates moderate pollution levels, which may persist due to the damp conditions. [...] Chennai expects moderate rain today with temperatures ranging from 25.8°C to 31.3°C and high humidity. Yesterday’s air quality was moderate (AQI 81), potentially lingering. Residents are advised to carry umbrellas and consider masks in traffic. The forecast indicates continuous rain throughout the upcoming week, making morning hours the best for outdoor activities before precip ...
#   AIMessage(content="The current weather in Chennai is expected to be moderate rainfall with temperatures ranging between 25.8°C and 31.3°C, amid overcast skies and 71% humidity. The city's air quality index recorded yesterday at 81 indicates moderate pollution levels, which may persist due to the damp conditions. Residents are advised to carry umbrellas and consider masks in traffic. The forecast indicates continuous rain throughout the upcoming week, making morning hours the best for outdoor activities before precipitation sets in.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 99, 'prompt_tokens': 990, 'total_tokens': 1089, 'completion_time': 0.112490394, 'prompt_time': 0.078738835, 'queue_time': 0.057390174, 'total_time': 0.191229229}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'finish_reason': 'stop', 'logprobs': None}, id='run--525cdaa0-c4c2-4f1a-8a53-e42878785791-0', usage_metadata={'input_tokens': 990, 'output_tokens': 99, 'total_tokens': 1089})]}

# %% [markdown]
# Case 2: Different Schema (Invoke with Transformation)

# %%
from typing import TypedDict, Annotated, Dict
from langgraph.graph import StateGraph, START, END
from langchain_core.messages import HumanMessage

# Define parent graph with different schema
class QueryState(TypedDict):
    query: str
    response: str

# Function to invoke subgraph
def search_agent(state: QueryState) -> Dict:
    # Transform from parent schema to subgraph schema
    subgraph_input = {
        "messages": [HumanMessage(content=state["query"])]
    }
    
    # Invoke the subgraph
    subgraph_result = search_app.invoke(subgraph_input)
    
    # Transform response back to parent schema
    assistant_message = subgraph_result["messages"][-1]
    return {"response": assistant_message.content}

# Create parent graph
parent_graph = StateGraph(QueryState)

# Add transformation node that invokes subgraph
parent_graph.add_node("search_agent", search_agent)

# Connect the flow
parent_graph.add_edge(START, "search_agent")
parent_graph.add_edge("search_agent", END)

# Compile parent graph
parent_app = parent_graph.compile()

# Run the parent graph
result = parent_app.invoke({"query": "How is the weather in Chennai?", "response": ""})
print(result)
# Out:
# {'query': 'How is the weather in Chennai?', 'response': 'The weather in Chennai is partly cloudy with a temperature of 87°F (31°C). The humidity is 70% and the wind speed is 14 mph from the Northeast. There is a chance of rain in the next few days, with scattered clouds expected throughout the day.'}
